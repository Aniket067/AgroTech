# %%
#  Importing Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from collections import Counter
import joblib

# %%
#    Load Dataset
data = pd.read_csv('preprocessed2.csv')
data.head()
# Out:
#    Unnamed: 0                   State_Name District_Name       Season  \
# 0           0  Andaman and Nicobar Islands      NICOBARS  Kharif
# 1           1  Andaman and Nicobar Islands      NICOBARS  Kharif
# 2           2  Andaman and Nicobar Islands      NICOBARS  Kharif
# 3           3  Andaman and Nicobar Islands      NICOBARS  Whole Year
# 4           4  Andaman and Nicobar Islands      NICOBARS  Whole Year
#
#                   Crop
# 0             Arecanut
# 1  Other Kharif pulses
# 2                 Rice
# 3               Banana
# 4            Cashewnut

# %%
#  Data Cleaning
data['Season'] = data['Season'].str.rstrip()  # Remove extra whitespace
if 'Unnamed: 0' in data.columns:
    del data['Unnamed: 0']  # Remove unnamed index column
data.head()
# Out:
#                     State_Name District_Name      Season                 Crop
# 0  Andaman and Nicobar Islands      NICOBARS      Kharif             Arecanut
# 1  Andaman and Nicobar Islands      NICOBARS      Kharif  Other Kharif pulses
# 2  Andaman and Nicobar Islands      NICOBARS      Kharif                 Rice
# 3  Andaman and Nicobar Islands      NICOBARS  Whole Year               Banana
# 4  Andaman and Nicobar Islands      NICOBARS  Whole Year            Cashewnut

# %%
#  Preparing Training and Testing Data
training_data = list(np.array(data))
testing_data = training_data[100:120]  # Taking sample test data
header = ['State_Name', 'District_Name', 'Season', 'Crop']

# %%
# Helper Function for crop count

def unique_vals(data, col):
    return set([row[col] for row in data])

def class_counts(data):
    counts = {}
    for row in data:
        label = row[-1]
        if label not in counts:
            counts[label] = 0
        counts[label] += 1
    return counts

# %%
#  Defined Question Class for decision tree split

class Question:
    def __init__(self, column, value):
        self.column = column
        self.value = value
    
    def match(self, example):
        val = example[self.column]
        return val == self.value
    
    def __repr__(self):
        return f"Is {header[self.column]} == {str(self.value)}?"

# %%
#  Partition the dataset to clasify decision tree

def partition(data, question):
    true_rows, false_rows = [], []
    for row in data:
        if question.match(row):
            true_rows.append(row)
        else:
            false_rows.append(row)
    return true_rows, false_rows

# %%
#  Gini Impurity for best split

def gini(data):
    counts = class_counts(data)
    impurity = 1
    for lbl in counts:
        prob_of_lbl = counts[lbl] / float(len(data))
        impurity -= prob_of_lbl**2
    return impurity

def info_gain(left, right, current_uncertainty):
    p = float(len(left)) / (len(left) + len(right))
    return current_uncertainty - p * gini(left) - (1 - p) * gini(right)

# %%
#  Find the Best Split

def find_best_split(data):
    best_gain = 0
    best_question = None
    current_uncertainty = gini(data)
    n_features = len(data[0]) - 1
    
    for col in range(n_features):
        values = unique_vals(data, col)
        
        for val in values:
            question = Question(col, val)
            true_rows, false_rows = partition(data, question)
            
            if len(true_rows) == 0 or len(false_rows) == 0:
                continue
            
            gain = info_gain(true_rows, false_rows, current_uncertainty)
            
            if gain > best_gain:
                best_gain, best_question = gain, question
                
    return best_gain, best_question

# %%
# final node

class Leaf:
    def __init__(self, data):
        self.predictions = class_counts(data)

# %%
#  Decision Node store question

class Decision_Node:
    def __init__(self, question, true_branch, false_branch):
        self.question = question
        self.true_branch = true_branch
        self.false_branch = false_branch

# %%
# 🛠️ Build the Decision Tree

def build_tree(data):
    gain, question = find_best_split(data)
    
    if gain == 0:
        return Leaf(data)
    
    true_rows, false_rows = partition(data, question)
    true_branch = build_tree(true_rows)
    false_branch = build_tree(false_rows)
    
    return Decision_Node(question, true_branch, false_branch)

# %%
# 📈 Visualize the Tree

def print_tree(node, spacing=""):
    if isinstance(node, Leaf):
        print(spacing + "Predict", node.predictions)
        return

    print(spacing + str(node.question))
    print(spacing + "--> True:")
    print_tree(node.true_branch, spacing + "  ")
    
    print(spacing + "--> False:")
    print_tree(node.false_branch, spacing + "  ")

# %%
# 🧠 Classify New Data

def classify(row, node):
    if isinstance(node, Leaf):
        return node.predictions

    if node.question.match(row):
        return classify(row, node.true_branch)
    else:
        return classify(row, node.false_branch)

def print_leaf(counts):
    total = sum(counts.values()) * 1.0
    probs = {}
    for lbl in counts.keys():
        probs[lbl] = str(int(counts[lbl] / total * 100)) + "%"
    return probs

# %%
# 🚀 Train the Model
my_tree = build_tree(training_data)
print_tree(my_tree)
# Out:
# Is Season == Rabi?
# --> True:
#   Is State_Name == Karnataka?
#   --> True:
#     Is District_Name == DAKSHIN KANNAD?
#     --> True:
#       Predict {'Dry chillies': 10, 'Groundnut': 1, 'Horse-gram': 15, 'Paddy': 1, 'Rice': 18, 'Moong(Green Gram)': 17, 'Other  Rabi pulses': 11, 'Urad': 16, 'Gram': 1, 'Cowpea(Lobia)': 5}
#     --> False:
#       Is District_Name == UDUPI?
#       --> True:
#         Predict {'Groundnut': 15, 'Horse-gram': 16, 'Moong(Green Gram)': 16, 'Onion': 2, 'Rice': 17, 'Other  Rabi pulses': 9, 'Urad': 15, 'Dry chillies': 9, 'Gram': 3, 'Maize': 10, 'Rapeseed &Mustard': 1, 'Sunflower': 2, 'Cowpea(Lobia)': 5}
#       --> False:
#         Is District_Name == KODAGU?
#         --> True:
#           Predict {'Dry chillies': 1, 'Paddy': 1, 'Rice': 16, 'Groundnut': 6, 'Other  Rabi pulses': 11, 'Ragi': 9, 'Gram': 6, 'Horse-gram': 7, 'Maize': 8, 'Cowpea(Lobia)': 2, 'Peas & beans (Pulses)': 1}
#         --> False:
#           Is District_Name == KOLAR?
#           --> True:
#             Predict {'Dry chillies': 10, 'Groundnut': 14, 'Horse-gram': 18, 'Maize': 16, 'Paddy': 1, 'Ragi': 18, 'Rice': 3, 'Gram': 10, 'Moong(Green Gram)': 1, 'Onion': 10, 'Peas & beans (Pulses)': 4, 'Potato': 10, 'Sunflower': 8, 'Other  Rabi pulses': 9, 'Rapeseed &Mustard': 11, 'Cowpea(Lobia)': 5}
#           --> False:
#             Is District_Name == BENGALURU URBAN?
#             --> True:
#               Predict {'Dry chillies': 10, 'Groundnut': 13, 'Horse-gram': 18, 'Maize': 18, 'Ragi': 18, 'Peas & beans (Pulses)': 4, 'Sunflower': 4, 'Gram': 9, 'Other  Rabi pulses': 16, 'Rapeseed &Mustard': 11, 'Rice': 4, 'Potato': 9, 'Cowpea(Lobia)': 5, 'Jowar': 3, 'Linseed': 2, 'Moong(Green Gram)': 2, 'Onion': 2}
#             --> False:
#               Is District_Name == MANDYA?
#               --> True:
#                 Predict {'Dry chillies': 10, 'Groundnut': 14, 'Horse-gram': 18, 'Paddy': 1, 'Ragi': 18, 'Rice': 14, 'Gram': 14, 'Moong(Green Gram)': 17, 'Onion': 10, 'Peas & beans (Pulses)': 4, 'Potato': 10, 'Sunflower': 9, 'Other  Rabi pulses': 15, 'Urad': 16, 'Jowar': 5, 'Maize': 12, 'Wheat': 1, 'Rapeseed &Mustard': 1, 'Cowpea(Lobia)': 5}
#               --> False:
#                 Is District_Name == BANGALORE RURAL?
#                 --> True:
#                   Predict {'Paddy': 1, 'Rice': 13, 'Gram': 16, 'Groundnut': 14, 'Horse-gram': 17, 'Maize': 17, 'Peas & beans (Pulses)': 4, 'Potato': 10, 'Ragi': 17, 'Sunflower': 15, 'Moong(Green Gram)': 3, 'Other  Rabi pulses': 16, 'Rapeseed &Mustard': 11, 'Urad': 3, 'Wheat': 3, 'Dry chillies': 8, 'Onion': 9, 'Cowpea(Lobia)': 5}
#                 --> False:
#                   Is District_Name == HASSAN?
#                   --> True:
#                     Predict {'Dry chillies': 10, 'Groundnut': 14, 'Horse-gram': 18, 'Jowar': 17, 'Maize': 18, 'Paddy': 1, 'Ragi': 18, 'Rice': 18, 'Gram': 17, 'Moong(Green Gram)': 16, 'Onion': 4, 'Peas & beans (Pulses)': 4, 'Potato': 8, 'Sunflower': 15, 'Other  Rabi pulses': 16, 'Rapeseed &Mustard': 11, 'Urad': 16, 'Cowpea(Lobia)': 5}
#                   --> False:
#                     Is District_Name == MYSORE?
#                     --> True:
#                       Predict {'Dry chillies': 10, 'Groundnut': 15, 'Horse-gram': 18, 'Jowar': 17, 'Maize': 18, 'Paddy': 1, 'Ragi': 18, 'Rice': 14, 'Wheat': 1, 'Gram': 17, 'Moong(Green Gram)': 16, 'Peas & beans (Pulses)': 4, 'Sunflower': 13, 'Other  Rabi pulses': 16, 'Rapeseed &Mustard': 3, 'Urad': 15, 'Cotton(lint)': 1, 'Cowpea(Lobia)': 5, 'Linseed': 1, 'Onion': 1, 'Potato': 1}
#                     --> False:
#                       Is District_Name == CHAMARAJANAGAR?
#                       --> True:
#                         Predict {'Gram': 17, 'Groundnut': 13, 'Horse-gram': 17, 'Jowar': 8, 'Maize': 17, 'Moong(Green Gram)': 16, 'Onion': 10, 'Peas & beans (Pulses)': 4, 'Ragi': 17, 'Rice': 17, 'Sunflower': 17, 'Wheat': 4, 'Other  Rabi pulses': 16, 'Urad': 15, 'Dry chillies': 9, 'Cotton(lint)': 2, 'Cowpea(Lobia)': 4, 'Potato': 4, 'Rapeseed &Mustard': 1, 'Linseed': 1}
#                       --> False:
#                         Is District_Name == UTTAR KANNAD?
#                         --> True:
#                           Predict {'Dry chillies': 10, 'Groundnut': 17, 'Horse-gram': 18, 'Jowar': 16, 'Maize': 17, 'Paddy': 1, 'Ragi': 17, 'Rice': 18, 'Gram': 17, 'Linseed': 11, 'Moong(Green Gram)': 17, 'Sunflower': 17, 'Other  Rabi pulses': 16, 'Rapeseed &Mustard': 4, 'Safflower': 2, 'Urad': 16, 'Onion': 9, 'Cowpea(Lobia)': 5}
#                         --> False:
#                           Is District_Name == RAMANAGARA?
#                           --> True:
#                             Predict {'Gram': 5, 'Groundnut': 5, 'Horse-gram': 8, 'Maize': 8, 'Other  Rabi pulses': 8, 'Ragi': 8, 'Dry chillies': 5, 'Rapeseed &Mustard': 4, 'Cowpea(Lobia)': 2, 'Peas & beans (Pulses)': 2, 'Rice': 1}
#                           --> False:
#                             Is District_Name == CHIKBALLAPUR?
#                             --> True:
#                               Predict {'Dry chillies': 7, 'Groundnut': 5, 'Horse-gram': 8, 'Maize': 8, 'Onion': 8, 'Potato': 8, 'Ragi': 8, 'Rice': 3, 'Sunflower': 8, 'Gram': 7, 'Other  Rabi pulses': 1, 'Rapeseed &Mustard': 3, 'Cotton(lint)': 2, 'Cowpea(Lobia)': 3, 'Peas & beans (Pulses)': 2}
#                             --> False:
#                               Is District_Name == TUMKUR?
#                               --> True:
#                                 Predict {'Dry chillies': 10, 'Groundnut': 15, 'Horse-gram': 18, 'Jowar': 15, 'Maize': 18, 'Paddy': 1, 'Ragi': 18, 'Rice': 18, 'Wheat': 4, 'Gram': 17, 'Moong(Green Gram)': 13, 'Peas & beans (Pulses)': 4, 'Sunflower': 15, 'Other  Rabi pulses': 13, 'Rapeseed &Mustard': 11, 'Urad': 4, 'Linseed': 6, 'Safflower': 5, 'Onion': 8, 'Potato': 8, 'Cotton(lint)': 4, 'Cowpea(Lobia)': 5}
#                               --> False:
#                                 Is District_Name == CHITRADURGA?
#                                 --> True:
#                                   Predict {'Dry chillies': 10, 'Groundnut': 14, 'Horse-gram': 18, 'Jowar': 18, 'Maize': 18, 'Paddy': 1, 'Ragi': 18, 'Rice': 18, 'Wheat': 18, 'Gram': 17, 'Onion': 10, 'Peas & beans (Pulses)': 3, 'Safflower': 17, 'Sunflower': 17, 'Other  Rabi pulses': 15, 'Rapeseed &Mustard': 11, 'Bajra': 1, 'Cotton(lint)': 5, 'Cowpea(Lobia)': 5, 'Moong(Green Gram)': 1}
#                                 --> False:
#                                   Is District_Name == CHIKMAGALUR?
#                                   --> True:
#                                     Predict {'Groundnut': 14, 'Horse-gram': 18, 'Jowar': 18, 'Wheat': 14, 'Gram': 17, 'Moong(Green Gram)': 15, 'Onion': 4, 'Peas & beans (Pulses)': 4, 'Safflower': 14, 'Sunflower': 17, 'Other  Rabi pulses': 15, 'Rapeseed &Mustard': 11, 'Urad': 13, 'Ragi': 8, 'Dry chillies': 9, 'Potato': 9, 'Cowpea(Lobia)': 2, 'Linseed': 2}
#                                   --> False:
#                                     Is District_Name == BIDAR?
#                                     --> True:
#                                       Predict {'Dry chillies': 10, 'Groundnut': 15, 'Jowar': 18, 'Maize': 18, 'Paddy': 1, 'Rice': 7, 'Wheat': 18, 'Gram': 16, 'Linseed': 17, 'Onion': 10, 'Peas & beans (Pulses)': 4, 'Potato': 10, 'Safflower': 17, 'Sunflower': 17, 'Other  Rabi pulses': 16, 'Rapeseed &Mustard': 11}
#                                     --> False:
#                                       Is District_Name == SHIMOGA?
#                                       --> True:
#                                         Predict {'Dry chillies': 10, 'Groundnut': 15, 'Horse-gram': 18, 'Jowar': 18, 'Maize': 17, 'Wheat': 5, 'Gram': 17, 'Linseed': 16, 'Moong(Green Gram)': 17, 'Sunflower': 17, 'Other  Rabi pulses': 16, 'Ragi': 5, 'Rapeseed &Mustard': 10, 'Urad': 16, 'Rice': 1, 'Safflower': 7, 'Peas & beans (Pulses)': 1, 'Onion': 1, 'Cowpea(Lobia)': 5}
#                                       --> False:
#                                         Is District_Name == GULBARGA?
#                                         --> True:
#                                           Predict {'Dry chillies': 10, 'Groundnut': 15, 'Horse-gram': 15, 'Jowar': 18, 'Maize': 18, 'Paddy': 1, 'Rice': 18, 'Wheat': 18, 'Gram': 17, 'Linseed': 17, 'Onion': 10, 'Potato': 5, 'Safflower': 17, 'Sunflower': 17, 'Other  Rabi pulses': 11, 'Moong(Green Gram)': 1, 'Rapeseed &Mustard': 8, 'Bajra': 2}
#                                         --> False:
#                                           Is District_Name == BELLARY?
#                                           --> True:
#                                             Predict {'Dry chillies': 10, 'Groundnut': 15, 'Horse-gram': 18, 'Jowar': 18, 'Maize': 18, 'Ragi': 12, 'Wheat': 18, 'Bajra': 13, 'Gram': 17, 'Linseed': 13, 'Moong(Green Gram)': 15, 'Onion': 10, 'Safflower': 17, 'Sunflower': 17, 'Other  Rabi pulses': 15, 'Rapeseed &Mustard': 8, 'Urad': 15, 'Rice': 8, 'Cotton(lint)': 5, 'Cowpea(Lobia)': 5, 'Potato': 1}
#                                           --> False:
#                                             Is District_Name == DAVANGERE?
#                                             --> True:
#                                               Predict {'Gram': 17, 'Groundnut': 14, 'Horse-gram': 17, 'Jowar': 17, 'Linseed': 6, 'Maize': 17, 'Moong(Green Gram)': 14, 'Onion': 10, 'Rice': 2, 'Safflower': 15, 'Sunflower': 17, 'Wheat': 17, 'Other  Rabi pulses': 16, 'Rapeseed &Mustard': 11, 'Urad': 11, 'Ragi': 14, 'Dry chillies': 9, 'Peas & beans (Pulses)': 3, 'Bajra': 1, 'Cotton(lint)': 5, 'Cowpea(Lobia)': 5}
#                                             --> False:
#                                               Is District_Name == HAVERI?
#                                               --> True:
#                                                 Predict {'Gram': 17, 'Groundnut': 13, 'Horse-gram': 17, 'Jowar': 17, 'Linseed': 17, 'Maize': 17, 'Moong(Green Gram)': 17, 'Onion': 10, 'Safflower': 17, 'Sunflower': 17, 'Wheat': 17, 'Other  Rabi pulses': 16, 'Rapeseed &Mustard': 11, 'Urad': 16, 'Rice': 1, 'Dry chillies': 9, 'Peas & beans (Pulses)': 3, 'Cotton(lint)': 5, 'Cowpea(Lobia)': 5}
#                                               --> False:
#                                                 Is District_Name == BELGAUM?
#                                                 --> True:
#                                                   Predict {'Dry chillies': 10, 'Groundnut': 15, 'Horse-gram': 18, 'Jowar': 18, 'Maize': 18, 'Wheat': 18, 'Gram': 17, 'Linseed': 17, 'Moong(Green Gram)': 17, 'Onion': 10, 'Potato': 10, 'Safflower': 17, 'Sunflower': 17, 'Other  Rabi pulses': 16, 'Rapeseed &Mustard': 11, 'Peas & beans (Pulses)': 3, 'Cotton(lint)': 4, 'Cowpea(Lobia)': 5, 'Ragi': 2, 'Urad': 2}
#                                                 --> False:
#                                                   Is District_Name == DHARWAD?
#                                                   --> True:
#                                                     Predict {'Dry chillies': 9, 'Groundnut': 14, 'Horse-gram': 18, 'Jowar': 18, 'Maize': 18, 'Paddy': 1, 'Rice': 2, 'Wheat': 18, 'Gram': 17, 'Linseed': 17, 'Moong(Green Gram)': 17, 'Onion': 9, 'Safflower': 17, 'Sunflower': 17, 'Other  Rabi pulses': 16, 'Rapeseed &Mustard': 11, 'Urad': 4, 'Potato': 8, 'Cotton(lint)': 5, 'Cowpea(Lobia)': 5, 'Peas & beans (Pulses)': 1, 'Ragi': 1}
#                                                   --> False:
#                                                     Is District_Name == YADGIR?
#                                                     --> True:
#                                                       Predict {'Bajra': 2, 'Cowpea(Lobia)': 5, 'Dry chillies': 4, 'Gram': 5, 'Groundnut': 3, 'Horse-gram': 5, 'Jowar': 5, 'Linseed': 4, 'Maize': 5, 'Onion': 5, 'Rice': 5, 'Safflower': 5, 'Sunflower': 5, 'Wheat': 5, 'Cotton(lint)': 1, 'Moong(Green Gram)': 1, 'Rapeseed &Mustard': 1, 'Urad': 2}
#                                                     --> False:
#                                                       Is District_Name == KOPPAL?
#                                                       --> True:
#                                                         Predict {'Gram': 17, 'Groundnut': 13, 'Horse-gram': 17, 'Jowar': 17, 'Linseed': 17, 'Maize': 17, 'Onion': 10, 'Safflower': 17, 'Sunflower': 17, 'Wheat': 17, 'Moong(Green Gram)': 4, 'Other  Rabi pulses': 11, 'Urad': 13, 'Bajra': 1, 'Rice': 1, 'Rapeseed &Mustard': 1, 'Dry chillies': 9, 'Cotton(lint)': 5, 'Cowpea(Lobia)': 2}
#                                                       --> False:
#                                                         Is District_Name == RAICHUR?
#                                                         --> True:
#                                                           Predict {'Dry chillies': 10, 'Groundnut': 14, 'Horse-gram': 18, 'Jowar': 18, 'Maize': 11, 'Wheat': 18, 'Gram': 17, 'Linseed': 17, 'Onion': 10, 'Safflower': 17, 'Sunflower': 17, 'Other  Rabi pulses': 10, 'Rapeseed &Mustard': 4, 'Moong(Green Gram)': 6, 'Urad': 5, 'Rice': 2, 'Cotton(lint)': 2, 'Cowpea(Lobia)': 2}
#                                                         --> False:
#                                                           Is District_Name == BIJAPUR?
#                                                           --> True:
#                                                             Predict {'Dry chillies': 10, 'Groundnut': 14, 'Horse-gram': 17, 'Jowar': 18, 'Maize': 18, 'Wheat': 18, 'Gram': 17, 'Linseed': 17, 'Moong(Green Gram)': 3, 'Onion': 10, 'Safflower': 17, 'Sunflower': 17, 'Other  Rabi pulses': 12, 'Urad': 1, 'Rice': 3, 'Cotton(lint)': 5, 'Cowpea(Lobia)': 4, 'Potato': 1}
#                                                           --> False:
#                                                             Is District_Name == BAGALKOT?
#                                                             --> True:
#                                                               Predict {'Gram': 17, 'Groundnut': 13, 'Horse-gram': 17, 'Jowar': 17, 'Linseed': 17, 'Maize': 17, 'Onion': 10, 'Safflower': 17, 'Sunflower': 17, 'Wheat': 17, 'Other  Rabi pulses': 16, 'Rapeseed &Mustard': 9, 'Dry chillies': 9, 'Cotton(lint)': 5, 'Cowpea(Lobia)': 5}
#                                                             --> False:
#                                                               Predict {'Gram': 17, 'Groundnut': 13, 'Horse-gram': 17, 'Jowar': 17, 'Linseed': 17, 'Maize': 17, 'Onion': 10, 'Rice': 2, 'Safflower': 17, 'Sunflower': 17, 'Wheat': 17, 'Other  Rabi pulses': 12, 'Rapeseed &Mustard': 9, 'Dry chillies': 8, 'Peas & beans (Pulses)': 1, 'Cotton(lint)': 5, 'Cowpea(Lobia)': 4}
#   --> False:
#     Is State_Name == Andhra Pradesh?
#     --> True:
#       Is District_Name == ANANTAPUR?
#       --> True:
#         Predict {'Dry chillies': 13, 'Gram': 18, 'Groundnut': 18, 'Horse-gram': 18, 'Jowar': 18, 'Korra': 2, 'Maize': 18, 'Ragi': 17, 'Rice': 18, 'Sunflower': 7, 'Wheat': 16, 'Bajra': 15, 'Linseed': 9, 'Masoor': 1, 'Moong(Green Gram)': 13, 'Safflower': 15, 'Sesamum': 2, 'Arhar/Tur': 4, 'Onion': 14, 'Small millets': 8, 'Urad': 11, 'Other  Rabi pulses': 3, 'Rapeseed &Mustard': 1, 'Cowpea(Lobia)': 4, 'Brinjal': 3, 'Castor seed': 3, 'Coriander': 3, 'Cotton(lint)': 3, 'Potato': 2, 'Sweet potato': 3, 'Tobacco': 3, 'Tomato': 3, 'Cabbage': 2, 'Other Kharif pulses': 1}
#       --> False:
#         Is District_Name == KURNOOL?
#         --> True:
#           Predict {'Arhar/Tur': 15, 'Dry chillies': 17, 'Gram': 18, 'Groundnut': 18, 'Horse-gram': 18, 'Jowar': 18, 'Maize': 18, 'Moong(Green Gram)': 17, 'Rice': 18, 'Sunflower': 7, 'Urad': 18, 'Wheat': 17, 'Bajra': 16, 'Korra': 3, 'Sesamum': 16, 'Linseed': 6, 'Masoor': 1, 'Rapeseed &Mustard': 15, 'Safflower': 15, 'Onion': 15, 'Other  Rabi pulses': 6, 'other misc. pulses': 1, 'Small millets': 14, 'other oilseeds': 1, 'Ragi': 2, 'Cowpea(Lobia)': 4, 'Brinjal': 3, 'Cabbage': 3, 'Castor seed': 3, 'Coriander': 3, 'Cotton(lint)': 3, 'Potato': 2, 'Tobacco': 3, 'Tomato': 3, 'Soyabean': 2, 'Turmeric': 1, 'Dry ginger': 1, 'Papaya': 1}
#         --> False:
#           Is District_Name == KADAPA?
#           --> True:
#             Predict {'Dry chillies': 16, 'Gram': 18, 'Groundnut': 18, 'Horse-gram': 18, 'Jowar': 18, 'Ragi': 17, 'Rice': 18, 'Sunflower': 7, 'Urad': 17, 'Bajra': 17, 'Sesamum': 17, 'Wheat': 16, 'Maize': 14, 'Masoor': 1, 'Moong(Green Gram)': 13, 'Rapeseed &Mustard': 3, 'Arhar/Tur': 12, 'Korra': 2, 'Onion': 14, 'Safflower': 7, 'Samai': 2, 'Small millets': 12, 'Other  Rabi pulses': 8, 'other oilseeds': 1, 'Linseed': 3, 'Cowpea(Lobia)': 4, 'Brinjal': 3, 'Cabbage': 1, 'Castor seed': 3, 'Coriander': 3, 'Cotton(lint)': 3, 'Dry ginger': 1, 'Papaya': 2, 'Potato': 2, 'Soyabean': 2, 'Sweet potato': 3, 'Tobacco': 3, 'Tomato': 3, 'Turmeric': 2, 'Other Kharif pulses': 1}
#           --> False:
#             Is District_Name == WEST GODAVARI?
#             --> True:
#               Predict {'Dry chillies': 17, 'Groundnut': 18, 'Horse-gram': 17, 'Jowar': 15, 'Maize': 18, 'Moong(Green Gram)': 18, 'Rice': 18, 'Urad': 18, 'Gram': 6, 'Safflower': 2, 'Sesamum': 16, 'Arhar/Tur': 11, 'Other  Rabi pulses': 6, 'other misc. pulses': 1, 'Onion': 1, 'other oilseeds': 2, 'Ragi': 1, 'Sunflower': 5, 'Rapeseed &Mustard': 2, 'Cowpea(Lobia)': 4, 'Brinjal': 3, 'Cabbage': 2, 'Sweet potato': 1, 'Tobacco': 3, 'Tomato': 3}
#             --> False:
#               Is District_Name == GUNTUR?
#               --> True:
#                 Predict {'Arhar/Tur': 15, 'Dry chillies': 17, 'Gram': 18, 'Groundnut': 18, 'Jowar': 18, 'Maize': 18, 'Moong(Green Gram)': 18, 'Rice': 18, 'Sesamum': 17, 'Urad': 18, 'Varagu': 5, 'Bajra': 10, 'Masoor': 1, 'Ragi': 10, 'Rapeseed &Mustard': 15, 'Horse-gram': 3, 'Onion': 13, 'Small millets': 6, 'other oilseeds': 3, 'Safflower': 1, 'Sunflower': 4, 'Linseed': 1, 'Wheat': 1, 'Brinjal': 3, 'Cabbage': 3, 'Castor seed': 3, 'Coriander': 1, 'Cowpea(Lobia)': 1, 'Sweet potato': 2, 'Tobacco': 3, 'Tomato': 3, 'Soyabean': 2, 'Cotton(lint)': 1}
#               --> False:
#                 Is District_Name == PRAKASAM?
#                 --> True:
#                   Predict {'Dry chillies': 17, 'Gram': 18, 'Groundnut': 18, 'Horse-gram': 17, 'Jowar': 18, 'Maize': 18, 'Moong(Green Gram)': 18, 'Ragi': 18, 'Rice': 18, 'Sesamum': 18, 'Sunflower': 7, 'Urad': 18, 'Varagu': 6, 'Arhar/Tur': 12, 'Bajra': 16, 'Masoor': 1, 'Rapeseed &Mustard': 11, 'Korra': 2, 'Onion': 14, 'Other  Rabi pulses': 5, 'Samai': 2, 'Small millets': 14, 'Wheat': 2, 'other oilseeds': 2, 'Safflower': 4, 'Cowpea(Lobia)': 4, 'Brinjal': 3, 'Cabbage': 3, 'Castor seed': 3, 'Coriander': 3, 'Cotton(lint)': 3, 'Soyabean': 2, 'Sweet potato': 3, 'Tobacco': 3, 'Tomato': 3, 'Turmeric': 3}
#                 --> False:
#                   Is District_Name == KRISHNA?
#                   --> True:
#                     Predict {'Dry chillies': 17, 'Groundnut': 18, 'Horse-gram': 17, 'Jowar': 17, 'Maize': 18, 'Moong(Green Gram)': 18, 'Rice': 18, 'Sesamum': 17, 'Urad': 18, 'Arhar/Tur': 9, 'Gram': 17, 'Ragi': 2, 'Rapeseed &Mustard': 14, 'Safflower': 1, 'Onion': 14, 'Other  Rabi pulses': 3, 'other oilseeds': 2, 'Sunflower': 4, 'Bajra': 1, 'Linseed': 2, 'Brinjal': 3, 'Cabbage': 3, 'Castor seed': 3, 'Sweet potato': 3, 'Tobacco': 3, 'Tomato': 3}
#                   --> False:
#                     Is District_Name == CHITTOOR?
#                     --> True:
#                       Predict {'Dry chillies': 17, 'Groundnut': 18, 'Horse-gram': 18, 'Ragi': 18, 'Rice': 18, 'Sunflower': 7, 'Maize': 17, 'Sesamum': 16, 'Bajra': 15, 'Gram': 9, 'Jowar': 8, 'Linseed': 10, 'Moong(Green Gram)': 15, 'Urad': 15, 'Onion': 14, 'Other  Rabi pulses': 9, 'other misc. pulses': 1, 'Rapeseed &Mustard': 2, 'Wheat': 6, 'Arhar/Tur': 8, 'other oilseeds': 1, 'Cowpea(Lobia)': 4, 'Brinjal': 3, 'Cabbage': 3, 'Coriander': 3, 'Cotton(lint)': 3, 'Potato': 2, 'Sweet potato': 3, 'Tobacco': 3, 'Tomato': 3, 'Other Kharif pulses': 1}
#                     --> False:
#                       Is District_Name == SPSR NELLORE?
#                       --> True:
#                         Predict {'Arhar/Tur': 14, 'Dry chillies': 17, 'Groundnut': 18, 'Horse-gram': 17, 'Jowar': 17, 'Moong(Green Gram)': 18, 'Ragi': 17, 'Rice': 18, 'Sesamum': 17, 'Sunflower': 7, 'Urad': 18, 'Maize': 14, 'Bajra': 12, 'Gram': 16, 'Masoor': 1, 'Other  Rabi pulses': 5, 'Safflower': 4, 'Onion': 7, 'other oilseeds': 2, 'Cowpea(Lobia)': 4, 'Brinjal': 3, 'Castor seed': 2, 'Cotton(lint)': 3, 'Soyabean': 2, 'Sweet potato': 3, 'Tobacco': 3, 'Tomato': 3, 'Rapeseed &Mustard': 1}
#                       --> False:
#                         Is District_Name == SRIKAKULAM?
#                         --> True:
#                           Predict {'Dry chillies': 17, 'Groundnut': 18, 'Horse-gram': 18, 'Jowar': 13, 'Maize': 17, 'Moong(Green Gram)': 18, 'Ragi': 18, 'Rice': 18, 'Sesamum': 18, 'Urad': 18, 'Wheat': 1, 'Onion': 15, 'Safflower': 1, 'other oilseeds': 2, 'Sunflower': 5, 'Other  Rabi pulses': 1, 'Gram': 5, 'Arhar/Tur': 3, 'Brinjal': 3, 'Cabbage': 3, 'Sweet potato': 1, 'Tobacco': 1, 'Tomato': 3}
#                         --> False:
#                           Is District_Name == VISAKHAPATANAM?
#                           --> True:
#                             Predict {'Dry chillies': 17, 'Gram': 17, 'Groundnut': 18, 'Horse-gram': 18, 'Jowar': 17, 'Maize': 18, 'Moong(Green Gram)': 18, 'Ragi': 18, 'Rice': 18, 'Sesamum': 18, 'Urad': 18, 'Safflower': 1, 'Arhar/Tur': 10, 'Onion': 14, 'Other  Rabi pulses': 14, 'other misc. pulses': 1, 'Rapeseed &Mustard': 1, 'Bajra': 1, 'other oilseeds': 3, 'Varagu': 1, 'Sunflower': 5, 'Cowpea(Lobia)': 4, 'Brinjal': 3, 'Cabbage': 3, 'Niger seed': 3, 'Sweet potato': 3, 'Tobacco': 3, 'Tomato': 3, 'Other Kharif pulses': 1, 'Potato': 1, 'Turmeric': 1}
#                           --> False:
#                             Is District_Name == EAST GODAVARI?
#                             --> True:
#                               Predict {'Dry chillies': 17, 'Groundnut': 17, 'Horse-gram': 18, 'Jowar': 13, 'Maize': 18, 'Moong(Green Gram)': 18, 'Ragi': 14, 'Rice': 18, 'Sesamum': 18, 'Urad': 18, 'Other  Rabi pulses': 6, 'Gram': 16, 'Rapeseed &Mustard': 1, 'Safflower': 1, 'Bajra': 4, 'Linseed': 1, 'Onion': 14, 'other misc. pulses': 1, 'Samai': 1, 'Small millets': 1, 'other oilseeds': 3, 'Sunflower': 4, 'Arhar/Tur': 5, 'Cowpea(Lobia)': 4, 'Brinjal': 3, 'Cabbage': 3, 'Mesta': 3, 'Tobacco': 3, 'Tomato': 3, 'Sweet potato': 2}
#                             --> False:
#                               Predict {'Dry chillies': 17, 'Gram': 17, 'Groundnut': 18, 'Horse-gram': 18, 'Jowar': 13, 'Maize': 18, 'Moong(Green Gram)': 18, 'Ragi': 18, 'Rice': 18, 'Sesamum': 18, 'Urad': 18, 'Linseed': 1, 'Onion': 14, 'Other  Rabi pulses': 2, 'Rapeseed &Mustard': 2, 'other oilseeds': 3, 'Sunflower': 4, 'Arhar/Tur': 2, 'Bajra': 2, 'Brinjal': 3, 'Cabbage': 3, 'Niger seed': 3, 'Potato': 1, 'Sweet potato': 3, 'Tobacco': 3, 'Tomato': 3, 'Papaya': 1}
#     --> False:
#       Is State_Name == Maharashtra?
#       --> True:
#         Is District_Name == SINDHUDURG?
#         --> True:
#           Predict {'Other  Rabi pulses': 12, 'Maize': 13, 'Other Cereals & Millets': 2, 'Rapeseed &Mustard': 9, 'Small millets': 3, 'Sesamum': 1}
#         --> False:
#           Is District_Name == RATNAGIRI?
#           --> True:
#             Predict {'Other  Rabi pulses': 12, 'Gram': 1, 'Rapeseed &Mustard': 12, 'Small millets': 2, 'Maize': 9, 'Other Cereals & Millets': 1}
#           --> False:
#             Is District_Name == RAIGAD?
#             --> True:
#               Predict {'Other  Rabi pulses': 12, 'Gram': 14, 'Other Cereals & Millets': 2, 'Rapeseed &Mustard': 12, 'Sesamum': 7, 'Small millets': 2, 'Maize': 4}
#             --> False:
#               Is District_Name == THANE?
#               --> True:
#                 Predict {'Other  Rabi pulses': 12, 'Gram': 17, 'Other Cereals & Millets': 2, 'Rapeseed &Mustard': 15, 'Sesamum': 14, 'Sunflower': 1, 'Wheat': 13, 'Maize': 10, 'Small millets': 3}
#               --> False:
#                 Is District_Name == GONDIA?
#                 --> True:
#                   Predict {'Gram': 16, 'Jowar': 1, 'Linseed': 15, 'Maize': 3, 'Sesamum': 5, 'Wheat': 15, 'Other  Rabi pulses': 9, 'Rapeseed &Mustard': 12, 'Soyabean': 1}
#                 --> False:
#                   Is District_Name == BHANDARA?
#                   --> True:
#                     Predict {'Jowar': 9, 'Other  Rabi pulses': 12, 'Wheat': 17, 'Gram': 17, 'Linseed': 17, 'Rapeseed &Mustard': 15, 'Safflower': 2, 'Sesamum': 11, 'Soyabean': 1}
#                   --> False:
#                     Is District_Name == KOLHAPUR?
#                     --> True:
#                       Predict {'Jowar': 17, 'Maize': 17, 'Other  Rabi pulses': 12, 'Wheat': 18, 'Gram': 17, 'Other Cereals & Millets': 1, 'Sunflower': 15, 'Small millets': 3, 'Soyabean': 1}
#                     --> False:
#                       Is District_Name == WASHIM?
#                       --> True:
#                         Predict {'Gram': 16, 'Jowar': 15, 'Other  Rabi pulses': 1, 'Safflower': 16, 'Sesamum': 1, 'Sunflower': 10, 'Wheat': 16, 'Soyabean': 1, 'Rapeseed &Mustard': 1, 'Maize': 1}
#                       --> False:
#                         Is District_Name == NAGPUR?
#                         --> True:
#                           Predict {'Jowar': 17, 'Other  Rabi pulses': 12, 'Wheat': 17, 'Gram': 17, 'Linseed': 17, 'Rapeseed &Mustard': 15, 'Sesamum': 7, 'Sunflower': 17, 'Soyabean': 1}
#                         --> False:
#                           Is District_Name == GADCHIROLI?
#                           --> True:
#                             Predict {'Jowar': 17, 'Maize': 15, 'Wheat': 17, 'Gram': 17, 'Linseed': 16, 'Other  Rabi pulses': 11, 'Rapeseed &Mustard': 15, 'Safflower': 1, 'Sesamum': 17, 'Sunflower': 4, 'Small millets': 2, 'Soyabean': 1}
#                           --> False:
#                             Is District_Name == CHANDRAPUR?
#                             --> True:
#                               Predict {'Jowar': 16, 'Other  Rabi pulses': 12, 'Wheat': 17, 'Gram': 17, 'Linseed': 16, 'Rapeseed &Mustard': 15, 'Safflower': 2, 'Sesamum': 11, 'Sunflower': 7, 'Maize': 2, 'Small millets': 2, 'Soyabean': 1}
#                             --> False:
#                               Is District_Name == DHULE?
#                               --> True:
#                                 Predict {'Jowar': 17, 'Maize': 17, 'Other  Rabi pulses': 11, 'Wheat': 18, 'Gram': 17, 'Rapeseed &Mustard': 9, 'Safflower': 1, 'Sesamum': 4, 'Sunflower': 5, 'Small millets': 2, 'Other Cereals & Millets': 1, 'Soyabean': 1}
#                               --> False:
#                                 Is District_Name == WARDHA?
#                                 --> True:
#                                   Predict {'Jowar': 17, 'Other  Rabi pulses': 9, 'Wheat': 17, 'Gram': 17, 'Linseed': 12, 'Maize': 4, 'Rapeseed &Mustard': 11, 'Safflower': 4, 'Sesamum': 5, 'Sunflower': 10, 'Soyabean': 1}
#                                 --> False:
#                                   Is District_Name == JALGAON?
#                                   --> True:
#                                     Predict {'Jowar': 17, 'Maize': 17, 'Wheat': 18, 'Gram': 17, 'Other  Rabi pulses': 2, 'Other Cereals & Millets': 1, 'Rapeseed &Mustard': 9, 'Safflower': 9, 'Sunflower': 14, 'Small millets': 1, 'Soyabean': 1}
#                                   --> False:
#                                     Is District_Name == AMRAVATI?
#                                     --> True:
#                                       Predict {'Jowar': 10, 'Other  Rabi pulses': 4, 'Wheat': 17, 'Gram': 17, 'Linseed': 3, 'Maize': 3, 'Rapeseed &Mustard': 9, 'Safflower': 17, 'Sesamum': 3, 'Sunflower': 17, 'Other Cereals & Millets': 1, 'Soyabean': 1}
#                                     --> False:
#                                       Is District_Name == YAVATMAL?
#                                       --> True:
#                                         Predict {'Other  Rabi pulses': 8, 'Wheat': 17, 'Gram': 17, 'Jowar': 9, 'Linseed': 8, 'Rapeseed &Mustard': 8, 'Safflower': 13, 'Sesamum': 5, 'Sunflower': 7, 'Soyabean': 1, 'Maize': 1}
#                                       --> False:
#                                         Is District_Name == AKOLA?
#                                         --> True:
#                                           Predict {'Jowar': 13, 'Other  Rabi pulses': 3, 'Wheat': 18, 'Gram': 17, 'Maize': 9, 'Rapeseed &Mustard': 11, 'Safflower': 17, 'Sesamum': 1, 'Sunflower': 17, 'Soyabean': 1}
#                                         --> False:
#                                           Is District_Name == BULDHANA?
#                                           --> True:
#                                             Predict {'Jowar': 17, 'Maize': 17, 'Wheat': 18, 'Gram': 17, 'Linseed': 1, 'Other  Rabi pulses': 3, 'Other Cereals & Millets': 1, 'Rapeseed &Mustard': 8, 'Safflower': 16, 'Sunflower': 15, 'Small millets': 2, 'Soyabean': 1}
#                                           --> False:
#                                             Is District_Name == NANDURBAR?
#                                             --> True:
#                                               Predict {'Gram': 16, 'Other  Rabi pulses': 5, 'Safflower': 10, 'Small millets': 4, 'Sunflower': 12, 'Wheat': 16, 'Jowar': 14, 'Maize': 13, 'Rapeseed &Mustard': 11, 'Other Cereals & Millets': 1, 'Soyabean': 1}
#                                             --> False:
#                                               Is District_Name == SANGLI?
#                                               --> True:
#                                                 Predict {'Jowar': 17, 'Maize': 17, 'Other  Rabi pulses': 10, 'Wheat': 18, 'Gram': 17, 'Other Cereals & Millets': 1, 'Rapeseed &Mustard': 15, 'Safflower': 17, 'Sesamum': 5, 'Sunflower': 17, 'Small millets': 2, 'Soyabean': 1}
#                                               --> False:
#                                                 Is District_Name == NASHIK?
#                                                 --> True:
#                                                   Predict {'Jowar': 17, 'Maize': 17, 'Other  Rabi pulses': 12, 'Wheat': 18, 'Gram': 17, 'Linseed': 2, 'Other Cereals & Millets': 2, 'Rapeseed &Mustard': 14, 'Safflower': 12, 'Sesamum': 4, 'Sunflower': 12, 'Small millets': 4, 'Soyabean': 1}
#                                                 --> False:
#                                                   Is District_Name == PUNE?
#                                                   --> True:
#                                                     Predict {'Jowar': 17, 'Maize': 17, 'Other  Rabi pulses': 12, 'Wheat': 18, 'Gram': 17, 'Linseed': 10, 'Other Cereals & Millets': 2, 'Rapeseed &Mustard': 13, 'Safflower': 17, 'Sesamum': 17, 'Sunflower': 17, 'Small millets': 5, 'Soyabean': 1}
#                                                   --> False:
#                                                     Is District_Name == NANDED?
#                                                     --> True:
#                                                       Predict {'Jowar': 17, 'Other  Rabi pulses': 8, 'Wheat': 18, 'Gram': 17, 'Linseed': 12, 'Other Cereals & Millets': 2, 'Rapeseed &Mustard': 13, 'Safflower': 17, 'Sesamum': 15, 'Sunflower': 16, 'Small millets': 5, 'Maize': 14, 'Soyabean': 1}
#                                                     --> False:
#                                                       Is District_Name == AHMEDNAGAR?
#                                                       --> True:
#                                                         Predict {'Jowar': 17, 'Maize': 17, 'Other  Rabi pulses': 12, 'Wheat': 18, 'Gram': 17, 'Linseed': 17, 'Other Cereals & Millets': 2, 'Rapeseed &Mustard': 12, 'Safflower': 17, 'Sesamum': 15, 'Sunflower': 17, 'Small millets': 4, 'Soyabean': 1}
#                                                       --> False:
#                                                         Is District_Name == SATARA?
#                                                         --> True:
#                                                           Predict {'Jowar': 17, 'Maize': 17, 'Other  Rabi pulses': 12, 'Wheat': 18, 'Gram': 17, 'Linseed': 10, 'Other Cereals & Millets': 2, 'Rapeseed &Mustard': 15, 'Safflower': 17, 'Sesamum': 12, 'Sunflower': 17, 'Small millets': 5, 'Soyabean': 1}
#                                                         --> False:
#                                                           Is District_Name == AURANGABAD?
#                                                           --> True:
#                                                             Predict {'Jowar': 17, 'Maize': 17, 'Wheat': 18, 'Gram': 17, 'Linseed': 14, 'Rapeseed &Mustard': 10, 'Safflower': 17, 'Sunflower': 16, 'Small millets': 1, 'Soyabean': 1, 'Other  Rabi pulses': 1}
#                                                           --> False:
#                                                             Is District_Name == PALGHAR?
#                                                             --> True:
#                                                               Predict {'Gram': 1, 'Other  Rabi pulses': 1, 'Sunflower': 1}
#                                                             --> False:
#                                                               Is District_Name == SOLAPUR?
#                                                               --> True:
#                                                                 Predict {'Jowar': 17, 'Maize': 17, 'Other  Rabi pulses': 11, 'Wheat': 18, 'Gram': 17, 'Linseed': 17, 'Other Cereals & Millets': 2, 'Safflower': 17, 'Sesamum': 2, 'Sunflower': 17, 'Small millets': 5, 'Rapeseed &Mustard': 3, 'Soyabean': 1}
#                                                               --> False:
#                                                                 Is District_Name == OSMANABAD?
#                                                                 --> True:
#                                                                   Predict {'Jowar': 17, 'Other  Rabi pulses': 12, 'Wheat': 18, 'Gram': 17, 'Linseed': 17, 'Other Cereals & Millets': 2, 'Safflower': 17, 'Sunflower': 17, 'Small millets': 4, 'Maize': 11, 'Rapeseed &Mustard': 8, 'Soyabean': 1}
#                                                                 --> False:
#                                                                   Is District_Name == LATUR?
#                                                                   --> True:
#                                                                     Predict {'Jowar': 17, 'Maize': 15, 'Other  Rabi pulses': 12, 'Wheat': 18, 'Gram': 17, 'Linseed': 17, 'Other Cereals & Millets': 2, 'Rapeseed &Mustard': 15, 'Safflower': 17, 'Sunflower': 17, 'Small millets': 5, 'Soyabean': 1}
#                                                                   --> False:
#                                                                     Is District_Name == PARBHANI?
#                                                                     --> True:
#                                                                       Predict {'Jowar': 17, 'Maize': 16, 'Other  Rabi pulses': 11, 'Wheat': 18, 'Gram': 17, 'Linseed': 16, 'Other Cereals & Millets': 2, 'Rapeseed &Mustard': 15, 'Safflower': 17, 'Sesamum': 2, 'Sunflower': 16, 'Small millets': 3, 'Soyabean': 1}
#                                                                     --> False:
#                                                                       Is District_Name == HINGOLI?
#                                                                       --> True:
#                                                                         Predict {'Linseed': 13, 'Safflower': 16, 'Sunflower': 13, 'Gram': 15, 'Jowar': 14, 'Maize': 13, 'Other  Rabi pulses': 9, 'Rapeseed &Mustard': 10, 'Wheat': 15, 'Small millets': 3, 'Soyabean': 1}
#                                                                       --> False:
#                                                                         Is District_Name == BEED?
#                                                                         --> True:
#                                                                           Predict {'Jowar': 17, 'Maize': 17, 'Other  Rabi pulses': 11, 'Wheat': 18, 'Gram': 17, 'Linseed': 17, 'Rapeseed &Mustard': 15, 'Safflower': 17, 'Sunflower': 17, 'Soyabean': 1}
#                                                                         --> False:
#                                                                           Predict {'Jowar': 17, 'Maize': 16, 'Other  Rabi pulses': 10, 'Wheat': 18, 'Gram': 17, 'Linseed': 14, 'Rapeseed &Mustard': 12, 'Safflower': 16, 'Sunflower': 16, 'Small millets': 1, 'Soyabean': 1}
#       --> False:
#         Is State_Name == Uttar Pradesh?
#         --> True:
#           Is District_Name == AMROHA?
#           --> True:
#             Predict {'Barley': 18, 'Gram': 13, 'Masoor': 15, 'Peas & beans (Pulses)': 13, 'Rapeseed &Mustard': 18, 'Sunflower': 2, 'Wheat': 18, 'Maize': 6, 'Moong(Green Gram)': 2, 'Urad': 2, 'Onion': 11, 'Potato': 11, 'Other  Rabi pulses': 2, 'Garlic': 2}
#           --> False:
#             Is District_Name == GAUTAM BUDDHA NAGAR?
#             --> True:
#               Predict {'Barley': 18, 'Gram': 10, 'Masoor': 15, 'Peas & beans (Pulses)': 13, 'Rapeseed &Mustard': 18, 'Sunflower': 2, 'Wheat': 18, 'Maize': 4, 'Moong(Green Gram)': 2, 'Urad': 2, 'Onion': 10, 'Potato': 11, 'Other  Rabi pulses': 2, 'Garlic': 2, 'Coriander': 3, 'Tobacco': 1}
#             --> False:
#               Is District_Name == KASGANJ?
#               --> True:
#                 Predict {'Barley': 6, 'Coriander': 5, 'Garlic': 5, 'Gram': 5, 'Masoor': 6, 'Onion': 6, 'Peas & beans (Pulses)': 4, 'Potato': 6, 'Rapeseed &Mustard': 6, 'Tobacco': 6, 'Wheat': 6, 'Turmeric': 5, 'Maize': 1}
#               --> False:
#                 Is District_Name == BAGHPAT?
#                 --> True:
#                   Predict {'Barley': 18, 'Gram': 16, 'Masoor': 15, 'Peas & beans (Pulses)': 11, 'Rapeseed &Mustard': 18, 'Sunflower': 2, 'Wheat': 18, 'Maize': 4, 'Moong(Green Gram)': 2, 'Urad': 2, 'Linseed': 1, 'Onion': 11, 'Ragi': 1, 'Potato': 11, 'Other  Rabi pulses': 2, 'Coriander': 3, 'Tobacco': 1, 'Turmeric': 2}
#                 --> False:
#                   Is District_Name == MATHURA?
#                   --> True:
#                     Predict {'Barley': 18, 'Gram': 18, 'Masoor': 15, 'Peas & beans (Pulses)': 12, 'Rapeseed &Mustard': 18, 'Sunflower': 2, 'Wheat': 18, 'Maize': 4, 'Linseed': 1, 'Moong(Green Gram)': 2, 'Urad': 1, 'Onion': 11, 'Potato': 11, 'Garlic': 4, 'Other  Rabi pulses': 2, 'Coriander': 3}
#                   --> False:
#                     Is District_Name == FARRUKHABAD?
#                     --> True:
#                       Predict {'Barley': 18, 'Gram': 18, 'Masoor': 15, 'Peas & beans (Pulses)': 13, 'Rapeseed &Mustard': 18, 'Sunflower': 2, 'Wheat': 18, 'Castor seed': 1, 'Linseed': 1, 'Maize': 5, 'Moong(Green Gram)': 2, 'Urad': 2, 'Onion': 11, 'Potato': 11, 'Turmeric': 2, 'Garlic': 7, 'Other  Rabi pulses': 2, 'Tobacco': 9, 'Coriander': 6}
#                     --> False:
#                       Is District_Name == SAHARANPUR?
#                       --> True:
#                         Predict {'Barley': 18, 'Gram': 18, 'Masoor': 15, 'Peas & beans (Pulses)': 13, 'Rapeseed &Mustard': 18, 'Sunflower': 2, 'Wheat': 18, 'Maize': 4, 'Linseed': 1, 'Moong(Green Gram)': 2, 'Urad': 2, 'Onion': 10, 'Potato': 11, 'Turmeric': 10, 'Garlic': 6, 'Other  Rabi pulses': 2, 'Coriander': 5, 'Tobacco': 1}
#                       --> False:
#                         Is District_Name == GHAZIABAD?
#                         --> True:
#                           Predict {'Barley': 18, 'Gram': 14, 'Masoor': 15, 'Peas & beans (Pulses)': 11, 'Rapeseed &Mustard': 18, 'Sunflower': 2, 'Wheat': 18, 'Maize': 6, 'Moong(Green Gram)': 2, 'Urad': 2, 'Onion': 10, 'Ragi': 1, 'Potato': 11, 'Garlic': 4, 'Other  Rabi pulses': 2, 'Coriander': 7, 'Linseed': 1, 'Turmeric': 1}
#                         --> False:
#                           Is District_Name == BIJNOR?
#                           --> True:
#                             Predict {'Barley': 18, 'Gram': 18, 'Masoor': 15, 'Peas & beans (Pulses)': 13, 'Rapeseed &Mustard': 18, 'Sunflower': 2, 'Wheat': 18, 'Linseed': 3, 'Maize': 8, 'Moong(Green Gram)': 2, 'Urad': 2, 'Onion': 11, 'Potato': 11, 'Garlic': 3, 'Other  Rabi pulses': 2, 'Turmeric': 3}
#                           --> False:
#                             Is District_Name == MEERUT?
#                             --> True:
#                               Predict {'Barley': 18, 'Gram': 18, 'Masoor': 15, 'Peas & beans (Pulses)': 13, 'Rapeseed &Mustard': 18, 'Sunflower': 2, 'Wheat': 18, 'Maize': 6, 'Moong(Green Gram)': 2, 'Urad': 2, 'Onion': 11, 'Potato': 11, 'Turmeric': 7, 'Other  Rabi pulses': 2, 'Coriander': 7, 'Garlic': 4, 'Linseed': 1}
#                             --> False:
#                               Is District_Name == KANNAUJ?
#                               --> True:
#                                 Predict {'Barley': 18, 'Gram': 18, 'Masoor': 15, 'Peas & beans (Pulses)': 13, 'Rapeseed &Mustard': 18, 'Sunflower': 2, 'Wheat': 18, 'Maize': 9, 'Moong(Green Gram)': 2, 'Urad': 2, 'Onion': 11, 'Potato': 11, 'Turmeric': 5, 'Garlic': 7, 'Other  Rabi pulses': 2, 'Tobacco': 7, 'Coriander': 7, 'Linseed': 1}
#                               --> False:
#                                 Is District_Name == BULANDSHAHR?
#                                 --> True:
#                                   Predict {'Barley': 18, 'Gram': 17, 'Masoor': 15, 'Peas & beans (Pulses)': 13, 'Rapeseed &Mustard': 18, 'Sunflower': 2, 'Wheat': 18, 'Linseed': 1, 'Maize': 5, 'Moong(Green Gram)': 2, 'Urad': 2, 'Onion': 11, 'Potato': 11, 'Garlic': 7, 'Other  Rabi pulses': 2, 'Tobacco': 1, 'Coriander': 6, 'Turmeric': 4}
#                                 --> False:
#                                   Is District_Name == HATHRAS?
#                                   --> True:
#                                     Predict {'Barley': 18, 'Gram': 18, 'Masoor': 15, 'Peas & beans (Pulses)': 13, 'Rapeseed &Mustard': 18, 'Sunflower': 2, 'Wheat': 18, 'Linseed': 1, 'Maize': 6, 'Moong(Green Gram)': 2, 'Urad': 2, 'Onion': 11, 'Potato': 11, 'Turmeric': 4, 'Garlic': 7, 'Other  Rabi pulses': 2, 'Coriander': 7, 'Tobacco': 1}
#                                   --> False:
#                                     Is District_Name == SANT RAVIDAS NAGAR?
#                                     --> True:
#                                       Predict {'Barley': 18, 'Gram': 18, 'Linseed': 15, 'Masoor': 11, 'Peas & beans (Pulses)': 13, 'Rapeseed &Mustard': 18, 'Wheat': 18, 'Moong(Green Gram)': 1, 'Urad': 2, 'Onion': 11, 'Ragi': 2, 'Potato': 11, 'Garlic': 2, 'Other  Rabi pulses': 2, 'Coriander': 1, 'Maize': 3}
#                                     --> False:
#                                       Is District_Name == CHITRAKOOT?
#                                       --> True:
#                                         Predict {'Barley': 18, 'Gram': 18, 'Linseed': 18, 'Masoor': 15, 'Peas & beans (Pulses)': 13, 'Rapeseed &Mustard': 18, 'Sunflower': 1, 'Wheat': 18, 'Castor seed': 1, 'Ragi': 2, 'Moong(Green Gram)': 1, 'Onion': 11, 'Potato': 11, 'Other  Rabi pulses': 2, 'Coriander': 7, 'Garlic': 2, 'Maize': 1}
#                                       --> False:
#                                         Is District_Name == ALIGARH?
#                                         --> True:
#                                           Predict {'Barley': 18, 'Gram': 17, 'Masoor': 15, 'Peas & beans (Pulses)': 13, 'Rapeseed &Mustard': 18, 'Sunflower': 2, 'Wheat': 18, 'Maize': 5, 'Moong(Green Gram)': 2, 'Urad': 2, 'Onion': 11, 'Linseed': 2, 'Potato': 11, 'Turmeric': 8, 'Garlic': 7, 'Other  Rabi pulses': 2, 'Tobacco': 3, 'Coriander': 7}
#                                         --> False:
#                                           Is District_Name == BALLIA?
#                                           --> True:
#                                             Predict {'Barley': 18, 'Gram': 18, 'Linseed': 3, 'Masoor': 15, 'Peas & beans (Pulses)': 13, 'Rapeseed &Mustard': 18, 'Sunflower': 2, 'Wheat': 18, 'Maize': 15, 'Ragi': 3, 'Moong(Green Gram)': 1, 'Urad': 2, 'Onion': 11, 'Potato': 11, 'Turmeric': 5, 'Garlic': 7, 'Other  Rabi pulses': 2, 'Tobacco': 1, 'Coriander': 7}
#                                           --> False:
#                                             Is District_Name == ETAWAH?
#                                             --> True:
#                                               Predict {'Barley': 18, 'Gram': 18, 'Masoor': 14, 'Peas & beans (Pulses)': 13, 'Rapeseed &Mustard': 18, 'Sunflower': 2, 'Wheat': 18, 'Maize': 8, 'Moong(Green Gram)': 2, 'Urad': 2, 'Linseed': 2, 'Onion': 11, 'Potato': 11, 'Turmeric': 5, 'Garlic': 7, 'Other  Rabi pulses': 2, 'Coriander': 7}
#                                             --> False:
#                                               Is District_Name == ETAH?
#                                               --> True:
#                                                 Predict {'Barley': 18, 'Gram': 18, 'Linseed': 6, 'Masoor': 15, 'Peas & beans (Pulses)': 9, 'Rapeseed &Mustard': 18, 'Sunflower': 2, 'Wheat': 18, 'Maize': 6, 'Moong(Green Gram)': 2, 'Urad': 2, 'Onion': 11, 'Potato': 11, 'Turmeric': 3, 'Garlic': 7, 'Other  Rabi pulses': 2, 'Tobacco': 9, 'Coriander': 7}
#                                               --> False:
#                                                 Is District_Name == AMBEDKAR NAGAR?
#                                                 --> True:
#                                                   Predict {'Barley': 18, 'Gram': 18, 'Linseed': 7, 'Masoor': 15, 'Peas & beans (Pulses)': 13, 'Rapeseed &Mustard': 18, 'Sunflower': 2, 'Wheat': 18, 'Maize': 14, 'Moong(Green Gram)': 1, 'Urad': 2, 'Onion': 11, 'Potato': 11, 'Turmeric': 2, 'Garlic': 7, 'Other  Rabi pulses': 2, 'Tobacco': 9, 'Coriander': 7}
#                                                 --> False:
#                                                   Is District_Name == MAINPURI?
#                                                   --> True:
#                                                     Predict {'Barley': 18, 'Gram': 18, 'Masoor': 15, 'Peas & beans (Pulses)': 13, 'Rapeseed &Mustard': 18, 'Sunflower': 2, 'Wheat': 18, 'Linseed': 4, 'Maize': 6, 'Moong(Green Gram)': 2, 'Urad': 2, 'Onion': 11, 'Potato': 11, 'Garlic': 7, 'Other  Rabi pulses': 2, 'Tobacco': 4, 'Coriander': 7, 'Turmeric': 2}
#                                                   --> False:
#                                                     Is District_Name == BUDAUN?
#                                                     --> True:
#                                                       Predict {'Barley': 18, 'Gram': 18, 'Linseed': 7, 'Masoor': 15, 'Peas & beans (Pulses)': 13, 'Rapeseed &Mustard': 18, 'Sunflower': 2, 'Wheat': 18, 'Maize': 6, 'Moong(Green Gram)': 2, 'Urad': 2, 'Onion': 11, 'Potato': 11, 'Turmeric': 10, 'Garlic': 7, 'Other  Rabi pulses': 2, 'Tobacco': 9, 'Coriander': 7}
#                                                     --> False:
#                                                       Is District_Name == HAMIRPUR?
#                                                       --> True:
#                                                         Predict {'Barley': 18, 'Gram': 18, 'Linseed': 18, 'Masoor': 15, 'Peas & beans (Pulses)': 13, 'Rapeseed &Mustard': 18, 'Sunflower': 2, 'Wheat': 18, 'Castor seed': 1, 'Moong(Green Gram)': 2, 'Urad': 1, 'Maize': 2, 'Onion': 11, 'Potato': 11, 'Other  Rabi pulses': 2, 'Tobacco': 9, 'Coriander': 7, 'Garlic': 6, 'Turmeric': 1}
#                                                       --> False:
#                                                         Is District_Name == SHAMLI?
#                                                         --> True:
#                                                           Predict {'Barley': 3, 'Garlic': 3, 'Gram': 2, 'Masoor': 3, 'Onion': 3, 'Peas & beans (Pulses)': 3, 'Potato': 3, 'Rapeseed &Mustard': 3, 'Turmeric': 3, 'Wheat': 3}
#                                                         --> False:
#                                                           Is District_Name == HAPUR?
# ...
#                                             --> True:
#                                               Predict {'Rice': 18, 'Potato': 2, 'Sesamum': 7}
#                                             --> False:
#                                               Is District_Name == BANKURA?
#                                               --> True:
#                                                 Predict {'Rice': 18, 'Potato': 2, 'Sesamum': 9}
#                                               --> False:
#                                                 Is District_Name == DARJEELING?
#                                                 --> True:
#                                                   Predict {'Rice': 18, 'Potato': 2, 'Sesamum': 9}
#                                                 --> False:
#                                                   Is District_Name == MALDAH?
#                                                   --> True:
#                                                     Predict {'Rice': 18, 'Potato': 2, 'Sesamum': 9}
#                                                   --> False:
#                                                     Predict {'Rice': 108, 'Potato': 12, 'Sesamum': 60}
#                           --> False:
#                             Is District_Name == SOUTH WEST KHASI HILLS?
#                             --> True:
#                               Predict {'Potato': 1, 'Rice': 1}
#                             --> False:
#                               Is District_Name == WEST JAINTIA HILLS?
#                               --> True:
#                                 Predict {'Potato': 1, 'Rice': 1}
#                               --> False:
#                                 Is District_Name == NORTH GARO HILLS?
#                                 --> True:
#                                   Predict {'Potato': 1, 'Rice': 1}
#                                 --> False:
#                                   Is District_Name == SOUTH WEST GARO HILLS?
#                                   --> True:
#                                     Predict {'Potato': 1, 'Rice': 1}
#                                   --> False:
#                                     Is State_Name == Puducherry?
#                                     --> True:
#                                       Predict {'Rice': 6}
#                                     --> False:
#                                       Predict {'Rice': 77, 'Potato': 7}
#                   --> False:
#                     Is State_Name == Jharkhand?
#                     --> True:
#                       Is District_Name == KODERMA?
#                       --> True:
#                         Predict {'Ragi': 6, 'Maize': 5, 'Rice': 2}
#                       --> False:
#                         Is District_Name == DHANBAD?
#                         --> True:
#                           Predict {'Maize': 6, 'Ragi': 2, 'Rice': 1}
#                         --> False:
#                           Is District_Name == SAHEBGANJ?
#                           --> True:
#                             Predict {'Maize': 6, 'Ragi': 2, 'Rice': 2}
#                           --> False:
#                             Is District_Name == BOKARO?
#                             --> True:
#                               Predict {'Maize': 6, 'Ragi': 2, 'Rice': 2}
#                             --> False:
#                               Is District_Name == CHATRA?
#                               --> True:
#                                 Predict {'Maize': 6, 'Ragi': 2, 'Rice': 2}
#                               --> False:
#                                 Is District_Name == WEST SINGHBHUM?
#                                 --> True:
#                                   Predict {'Maize': 6, 'Rice': 6, 'Ragi': 1}
#                                 --> False:
#                                   Is District_Name == PAKUR?
#                                   --> True:
#                                     Predict {'Maize': 6, 'Rice': 6, 'Ragi': 1}
#                                   --> False:
#                                     Is District_Name == EAST SINGHBUM?
#                                     --> True:
#                                       Predict {'Rice': 6, 'Maize': 5, 'Ragi': 1}
#                                     --> False:
#                                       Is District_Name == SARAIKELA KHARSAWAN?
#                                       --> True:
#                                         Predict {'Maize': 5, 'Rice': 3, 'Ragi': 1}
#                                       --> False:
#                                         Is District_Name == JAMTARA?
#                                         --> True:
#                                           Predict {'Maize': 5, 'Ragi': 2, 'Rice': 2}
#                                         --> False:
#                                           Is District_Name == DEOGHAR?
#                                           --> True:
#                                             Predict {'Maize': 6, 'Rice': 6, 'Ragi': 2}
#                                           --> False:
#                                             Is District_Name == DUMKA?
#                                             --> True:
#                                               Predict {'Maize': 6, 'Rice': 6, 'Ragi': 2}
#                                             --> False:
#                                               Is District_Name == GODDA?
#                                               --> True:
#                                                 Predict {'Maize': 6, 'Rice': 6, 'Ragi': 2}
#                                               --> False:
#                                                 Is District_Name == GARHWA?
#                                                 --> True:
#                                                   Predict {'Maize': 5, 'Rice': 5, 'Ragi': 2}
#                                                 --> False:
#                                                   Is District_Name == PALAMU?
#                                                   --> True:
#                                                     Predict {'Maize': 6, 'Ragi': 3, 'Rice': 4}
#                                                   --> False:
#                                                     Is District_Name == LATEHAR?
#                                                     --> True:
#                                                       Predict {'Maize': 5, 'Rice': 5, 'Ragi': 4}
#                                                     --> False:
#                                                       Is District_Name == LOHARDAGA?
#                                                       --> True:
#                                                         Predict {'Ragi': 6, 'Rice': 6, 'Maize': 5}
#                                                       --> False:
#                                                         Predict {'Maize': 29, 'Ragi': 29, 'Rice': 29}
#                     --> False:
#                       Is State_Name == Meghalaya?
#                       --> True:
#                         Predict {'Rice': 81}
#                       --> False:
#                         Is State_Name == Manipur?
#                         --> True:
#                           Is District_Name == BISHNUPUR?
#                           --> True:
#                             Predict {'Dry chillies': 1, 'Jute': 1, 'Onion': 1, 'Rice': 1, 'Sugarcane': 1, 'Turmeric': 1}
#                           --> False:
#                             Is District_Name == TAMENGLONG?
#                             --> True:
#                               Predict {'Banana': 1, 'Dry chillies': 1, 'Dry ginger': 1, 'Rice': 1, 'Sugarcane': 1}
#                             --> False:
#                               Is District_Name == CHURACHANDPUR?
#                               --> True:
#                                 Predict {'Banana': 1, 'Cotton(lint)': 1, 'Dry chillies': 1, 'Dry ginger': 1, 'Maize': 1, 'Onion': 1, 'Rice': 1, 'Soyabean': 1, 'Sugarcane': 1, 'Turmeric': 1}
#                               --> False:
#                                 Is District_Name == IMPHAL WEST?
#                                 --> True:
#                                   Predict {'Onion': 1, 'Peas & beans (Pulses)': 1, 'Potato': 1, 'Rice': 1, 'Soyabean': 1}
#                                 --> False:
#                                   Is District_Name == IMPHAL EAST?
#                                   --> True:
#                                     Predict {'Banana': 1, 'Peas & beans (Pulses)': 1, 'Potato': 1, 'Rice': 1, 'Turmeric': 1}
#                                   --> False:
#                                     Is District_Name == THOUBAL?
#                                     --> True:
#                                       Predict {'Dry ginger': 1, 'Peas & beans (Pulses)': 1, 'Potato': 1, 'Rice': 1, 'Turmeric': 1}
#                                     --> False:
#                                       Is District_Name == SENAPATI?
#                                       --> True:
#                                         Predict {'Banana': 1, 'Dry chillies': 1, 'Dry ginger': 1, 'Maize': 1, 'Onion': 1, 'Peas & beans (Pulses)': 1, 'Potato': 1, 'Rice': 1, 'Soyabean': 1, 'Sweet potato': 1, 'Tapioca': 1, 'Turmeric': 1}
#                                       --> False:
#                                         Is District_Name == UKHRUL?
#                                         --> True:
#                                           Predict {'Banana': 1, 'Dry chillies': 1, 'Dry ginger': 1, 'Maize': 1, 'Peas & beans (Pulses)': 1, 'Potato': 1, 'Rice': 1, 'Sesamum': 1, 'Soyabean': 1, 'Turmeric': 1}
#                                         --> False:
#                                           Predict {'Banana': 1, 'Dry ginger': 1, 'Maize': 1, 'Peas & beans (Pulses)': 1, 'Potato': 1, 'Rice': 1, 'Sesamum': 1, 'Soyabean': 1}
#                         --> False:
#                           Is State_Name == Maharashtra?
#                           --> True:
#                             Predict {'Maize': 7}
#                           --> False:
#                             Is District_Name == HOWRAH?
#                             --> True:
#                               Predict {'Rice': 18, 'Dry chillies': 2}
#                             --> False:
#                               Is District_Name == HOOGHLY?
#                               --> True:
#                                 Predict {'Rice': 18, 'Dry chillies': 2, 'Sannhamp': 1}
#                               --> False:
#                                 Is District_Name == 24 PARAGANAS SOUTH?
#                                 --> True:
#                                   Predict {'Rice': 18, 'Dry chillies': 2, 'Maize': 1}
#                                 --> False:
#                                   Is District_Name == DINAJPUR DAKSHIN?
#                                   --> True:
#                                     Predict {'Rice': 18, 'Dry chillies': 2, 'Maize': 1}
#                                   --> False:
#                                     Is District_Name == 24 PARAGANAS NORTH?
#                                     --> True:
#                                       Predict {'Rice': 18, 'Dry chillies': 2, 'Sesamum': 2, 'Maize': 2}
#                                     --> False:
#                                       Is State_Name == West Bengal?
#                                       --> True:
#                                         Is District_Name == BARDHAMAN?
#                                         --> True:
#                                           Predict {'Rice': 18, 'Dry chillies': 2, 'Sannhamp': 1, 'Sesamum': 2, 'Groundnut': 6}
#                                         --> False:
#                                           Is District_Name == MEDINIPUR EAST?
#                                           --> True:
#                                             Predict {'Rice': 17, 'Dry chillies': 2, 'Sannhamp': 1, 'Sesamum': 10}
#                                           --> False:
#                                             Is District_Name == BIRBHUM?
#                                             --> True:
#                                               Predict {'Rice': 18, 'Dry chillies': 2, 'Sannhamp': 1, 'Sesamum': 1, 'Maize': 6, 'Groundnut': 4}
#                                             --> False:
#                                               Is District_Name == DINAJPUR UTTAR?
#                                               --> True:
#                                                 Predict {'Ragi': 7, 'Rice': 18, 'Dry chillies': 2, 'Sesamum': 8, 'Maize': 7}
#                                               --> False:
#                                                 Is District_Name == NADIA?
#                                                 --> True:
#                                                   Predict {'Rice': 18, 'Dry chillies': 2, 'Sesamum': 5, 'Maize': 7, 'Groundnut': 4}
#                                                 --> False:
#                                                   Is District_Name == PURULIA?
#                                                   --> True:
#                                                     Predict {'Ragi': 7, 'Rice': 18, 'Dry chillies': 2, 'Sesamum': 10, 'Maize': 7, 'Groundnut': 6, 'Jowar': 3, 'Small millets': 3}
#                                                   --> False:
#                                                     Is District_Name == DARJEELING?
#                                                     --> True:
#                                                       Predict {'Ragi': 7, 'Rice': 18, 'Dry chillies': 2, 'Sesamum': 9, 'Maize': 7, 'Groundnut': 4}
#                                                     --> False:
#                                                       Is District_Name == JALPAIGURI?
#                                                       --> True:
#                                                         Predict {'Ragi': 7, 'Rice': 18, 'Dry chillies': 2, 'Sesamum': 8, 'Maize': 7, 'Groundnut': 5}
#                                                       --> False:
#                                                         Is District_Name == COOCHBEHAR?
#                                                         --> True:
#                                                           Predict {'Ragi': 6, 'Rice': 18, 'Dry chillies': 2, 'Sesamum': 10, 'Maize': 7, 'Groundnut': 6, 'Small millets': 3}
#                                                         --> False:
#                                                           Is District_Name == BANKURA?
#                                                           --> True:
#                                                             Predict {'Rice': 18, 'Dry chillies': 2, 'Sannhamp': 1, 'Sesamum': 10, 'Maize': 6, 'Groundnut': 6, 'Small millets': 3}
#                                                           --> False:
#                                                             Is District_Name == MEDINIPUR WEST?
#                                                             --> True:
#                                                               Predict {'Rice': 18, 'Dry chillies': 2, 'Sannhamp': 1, 'Sesamum': 10, 'Maize': 5, 'Groundnut': 6}
#                                                             --> False:
#                                                               Is District_Name == MALDAH?
#                                                               --> True:
#                                                                 Predict {'Rice': 18, 'Dry chillies': 2, 'Sesamum': 8, 'Maize': 7, 'Groundnut': 6}
#                                                               --> False:
#                                                                 Predict {'Rice': 18, 'Dry chillies': 2, 'Sesamum': 10, 'Maize': 7, 'Groundnut': 6}
#                                       --> False:
#                                         Is State_Name == Puducherry?
#                                         --> True:
#                                           Predict {'Rice': 6}
#                                         --> False:
#                                           Predict {'Rice': 3, 'Sugarcane': 3}

# %%
# 💾 Save the trained model
joblib.dump(my_tree, 'decision_tree_model.pkl')
print("Model saved as 'decision_tree_model.pkl'!")
# Out:
# Model saved as 'decision_tree_model.pkl'!

# %%
# 🧪 Predict on a Random Sample from Dataset

import random

# Pick a random index (skip last column which is label)
random_index = random.randint(0, len(data) - 1)
sample = list(data.iloc[random_index])

# Separate input and true label
input_features = sample[:-1]  # ['State_Name', 'District_Name', 'Season']
true_label = sample[-1]       # 'Crop'

# Add dummy label at the end for structure
test_row = input_features + ["Unknown"]

# Predict
prediction = classify(test_row, my_tree)
predicted_crop = print_leaf(prediction)

# Display
print("\n🌾 Prediction on Random Sample from Dataset")
print(f"Input: {input_features}")
print(f"✅ True Crop: {true_label}")
print(f"🤖 Predicted Crop: {predicted_crop}")
# Out:
# 🌾 Prediction on Random Sample from Dataset
# Input: ['Uttarakhand', 'TEHRI GARHWAL', 'Kharif']
# ✅ True Crop: Dry chillies
# 🤖 Predicted Crop: {'Arhar/Tur': '8%', 'Horse-gram': '8%', 'Maize': '8%', 'Other Cereals & Millets': '5%', 'Other Kharif pulses': '8%', 'Potato': '6%', 'Ragi': '8%', 'Rice': '8%', 'Sesamum': '8%', 'Small millets': '5%', 'Soyabean': '8%', 'Urad': '8%', 'other oilseeds': '5%', 'Dry chillies': '0%', 'Ginger': '0%', 'Pulses total': '0%', 'Total foodgrain': '0%'}
